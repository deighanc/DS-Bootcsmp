# %% [markdown]
# ## Task 19 Data Science Bootcamp - Simple Linear regression

# %%
#import packages 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.linear_models
from sklearn.linear_model import LinearRegression
# render thev figure in the notebook
# %matplotlib inline 

# Import the data 
insurance_data = pd.read_csv("insurance.csv",delimiter=",")
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#Plot a scatter plot with age on the x-axis and charges on the y=axis 
x_train = insurance_data.loc[:,'age'].values
x_train_reshaped = np.array(x_train).reshape(-1,1)
y_train = insurance_data.loc[:,'charges'].values
y_train_reshaped = np.array(y_train).reshape(-1,1)
plt.scatter(x,y,color = 'b')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
#Using linear_model.LinearRegression() from sklearn, fit a model to your data and make predictions on data/
# Fit the model
# fit the model to the 2d array reshaped variables  - we previously recieved a value error when x and y where nto reshaped. 
#insurance_model.fit(x,y)
insurance_model = LinearRegression()
insurance_model.fit(x_train_reshaped,y_train_reshaped)

# Plot the data and model
y_pred = insurance_model.predict(x_train_reshaped)
plt.scatter(x_train_reshaped,y_train_reshaped,color = 'b')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
#plot another scatter plot with best line fit. 
plt.scatter(x_train, y_train, color='blue', label='Actual data')
plt.plot(x_train_reshaped, y_pred, color='red', linewidth=2, label='Best fit line')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.title('Scatter plot with best line fit')
plt.legend()
plt.show()

# %% [markdown]
# `The results show that an increase in age correlates with and increase insurance charges however the best line fit does not match perfectly with the data.`
